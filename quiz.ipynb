# %% [markdown]
# <a href="https://colab.research.google.com/github/iabbakr/Hamoyeee/blob/master/quiz.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

url = '/content/drive/MyDrive/Colab Notebooks/FoodBalanceSheets_E_Africa_NOFLAG.csv'
csv_df = pd.read_csv(url, encoding="latin-1", error_bad_lines=False)
csv_df.to_csv(url)

csv_df.describe(include='all')
# Out:
# <ipython-input-2-9cbe6604552f>:6: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   csv_df = pd.read_csv(url, encoding="latin-1", error_bad_lines=False)
#         Unnamed: 0.1    Unnamed: 0     Area Code   Area      Item Code  \
# count   60942.000000  60942.000000  60942.000000  60942   60942.000000
# unique           NaN           NaN           NaN     50            NaN
# top              NaN           NaN           NaN  Kenya            NaN
# freq             NaN           NaN           NaN   1560            NaN
# mean    30470.500000  30470.500000    134.282088    NaN    2691.453431
# std     17592.584389  17592.584389     72.692510    NaN    1052.588963
# min         0.000000      0.000000      4.000000    NaN    2501.000000
# 25%     15235.250000  15235.250000     74.000000    NaN    2562.000000
# 50%     30470.500000  30470.500000    136.000000    NaN    2630.000000
# ...

# %%
csv_df.head()
# Out:
#    Area Code     Area  Item Code         Item Element Code  \
# 0          4  Algeria       2501   Population          511
# 1          4  Algeria       2501   Population         5301
# 2          4  Algeria       2901  Grand Total          664
# 3          4  Algeria       2901  Grand Total          674
# 4          4  Algeria       2901  Grand Total          684
#
#                                   Element             Unit     Y2014  \
# 0           Total Population - Both sexes     1000 persons  38924.00
# 1                Domestic supply quantity      1000 tonnes      0.00
# 2           Food supply (kcal/capita/day)  kcal/capita/day   3377.00
# 3  Protein supply quantity (g/capita/day)     g/capita/day     94.90
# 4      Fat supply quantity (g/capita/day)     g/capita/day     80.06
#
#       Y2015     Y2016     Y2017     Y2018
# 0  39728.00  40551.00  41389.00  42228.00
# 1      0.00      0.00      0.00      0.00
# 2   3379.00   3372.00   3341.00   3322.00
# ...

# %%
csv_df.groupby('Y2016')['Y2017'].describe()
# Out:
#            count      mean  std       min       25%       50%       75%  \
# Y2016
# -3225.0      1.0     689.0  NaN     689.0     689.0     689.0     689.0
# -2051.0      1.0     206.0  NaN     206.0     206.0     206.0     206.0
# -1499.0      1.0    2665.0  NaN    2665.0    2665.0    2665.0    2665.0
# -1324.0      1.0    2555.0  NaN    2555.0    2555.0    2555.0    2555.0
# -1088.0      1.0     457.0  NaN     457.0     457.0     457.0     457.0
# ...          ...       ...  ...       ...       ...       ...       ...
#  94447.0     1.0   96443.0  NaN   96443.0   96443.0   96443.0   96443.0
#  103603.0    1.0  106400.0  NaN  106400.0  106400.0  106400.0  106400.0
#  116483.0    1.0  112625.0  NaN  112625.0  112625.0  112625.0  112625.0
#  119330.0    1.0  117702.0  NaN  117702.0  117702.0  117702.0  117702.0
#  185960.0    1.0  190873.0  NaN  190873.0  190873.0  190873.0  190873.0
#
#                 max
# Y2016
# -3225.0       689.0
# -2051.0       206.0
# -1499.0      2665.0
# ...

# %%
csv_df.head()
# Out:
#    Unnamed: 0.1  Unnamed: 0  Area Code     Area  Item Code         Item  \
# 0             0           0          4  Algeria       2501   Population
# 1             1           1          4  Algeria       2501   Population
# 2             2           2          4  Algeria       2901  Grand Total
# 3             3           3          4  Algeria       2901  Grand Total
# 4             4           4          4  Algeria       2901  Grand Total
#
#   Element Code                                 Element             Unit  \
# 0          511           Total Population - Both sexes     1000 persons
# 1         5301                Domestic supply quantity      1000 tonnes
# 2          664           Food supply (kcal/capita/day)  kcal/capita/day
# 3          674  Protein supply quantity (g/capita/day)     g/capita/day
# 4          684      Fat supply quantity (g/capita/day)     g/capita/day
#
#       Y2014     Y2015     Y2016     Y2017     Y2018
# ...

# %%
csv_df.groupby('Y2017')['Area'].sum()
# Out:
# Y2017
# -1582.0                       EgyptEgypt
# -1200.0                       Mozambique
# -1159.0                       Mozambique
# -865.0       United Republic of Tanzania
# -860.0       United Republic of Tanzania
#                         ...
#  96443.0                           Egypt
#  106400.0                       Ethiopia
#  112625.0                        Nigeria
#  117702.0                        Nigeria
#  190873.0                        Nigeria
# Name: Area, Length: 4537, dtype: object

# %%
csv_df.groupby('Y2017')['Area'].describe()
# Out:
#           count unique                          top freq
# Y2017
# -1582.0       2      1                        Egypt    2
# -1200.0       1      1                   Mozambique    1
# -1159.0       1      1                   Mozambique    1
# -865.0        1      1  United Republic of Tanzania    1
# -860.0        1      1  United Republic of Tanzania    1
# ...         ...    ...                          ...  ...
#  96443.0      1      1                        Egypt    1
#  106400.0     1      1                     Ethiopia    1
#  112625.0     1      1                      Nigeria    1
#  117702.0     1      1                      Nigeria    1
#  190873.0     1      1                      Nigeria    1
#
# [4537 rows x 4 columns]

# %%
csv_df.groupby('Y2014').describe()
# Out:
#           Unnamed: 0.1                                                         \
#                  count     mean       std      min      25%      50%      75%
# Y2014
# -1796.0            1.0  44050.0       NaN  44050.0  44050.0  44050.0  44050.0
# -1631.0            1.0  44013.0       NaN  44013.0  44013.0  44013.0  44013.0
# -849.0             2.0  33841.0  4.242641  33838.0  33839.5  33841.0  33842.5
# -838.0             1.0  44603.0       NaN  44603.0  44603.0  44603.0  44603.0
# -685.0             1.0  37479.0       NaN  37479.0  37479.0  37479.0  37479.0
# ...                ...      ...       ...      ...      ...      ...      ...
#  90425.0           1.0   8859.0       NaN   8859.0   8859.0   8859.0   8859.0
#  98094.0           1.0  11631.0       NaN  11631.0  11631.0  11631.0  11631.0
#  108756.0          1.0  43132.0       NaN  43132.0  43132.0  43132.0  43132.0
#  109593.0          1.0  43128.0       NaN  43128.0  43128.0  43128.0  43128.0
# ...

# %%
csv_df.groupby('Y2015').describe()
# Out:
#           Unnamed: 0.1                                                   \
#                  count     mean std      min      25%      50%      75%
# Y2015
# -3161.0            1.0  49834.0 NaN  49834.0  49834.0  49834.0  49834.0
# -2152.0            1.0  49894.0 NaN  49894.0  49894.0  49894.0  49894.0
# -1284.0            1.0  51233.0 NaN  51233.0  51233.0  51233.0  51233.0
# -907.0             1.0  58111.0 NaN  58111.0  58111.0  58111.0  58111.0
# -887.0             1.0  51337.0 NaN  51337.0  51337.0  51337.0  51337.0
# ...                ...      ...  ..      ...      ...      ...      ...
#  92443.0           1.0   8859.0 NaN   8859.0   8859.0   8859.0   8859.0
#  100835.0          1.0  11631.0 NaN  11631.0  11631.0  11631.0  11631.0
#  110798.0          1.0  43132.0 NaN  43132.0  43132.0  43132.0  43132.0
#  111663.0          1.0  43128.0 NaN  43128.0  43128.0  43128.0  43128.0
#  181137.0          1.0  42972.0 NaN  42972.0  42972.0  42972.0  42972.0
#
# ...

# %%
csv_df.groupby('Y2016').describe()
# Out:
#           Unnamed: 0.1                                                   \
#                  count     mean std      min      25%      50%      75%
# Y2016
# -3225.0            1.0  37479.0 NaN  37479.0  37479.0  37479.0  37479.0
# -2051.0            1.0  37495.0 NaN  37495.0  37495.0  37495.0  37495.0
# -1499.0            1.0  49834.0 NaN  49834.0  49834.0  49834.0  49834.0
# -1324.0            1.0  49894.0 NaN  49894.0  49894.0  49894.0  49894.0
# -1088.0            1.0  37525.0 NaN  37525.0  37525.0  37525.0  37525.0
# ...                ...      ...  ..      ...      ...      ...      ...
#  94447.0           1.0   8859.0 NaN   8859.0   8859.0   8859.0   8859.0
#  103603.0          1.0  11631.0 NaN  11631.0  11631.0  11631.0  11631.0
#  116483.0          1.0  43132.0 NaN  43132.0  43132.0  43132.0  43132.0
#  119330.0          1.0  43128.0 NaN  43128.0  43128.0  43128.0  43128.0
#  185960.0          1.0  42972.0 NaN  42972.0  42972.0  42972.0  42972.0
#
# ...

# %%
csv_df.groupby('Y2017').describe()
# Out:
#                                          count          mean           std  \
# Element
# Domestic supply quantity                5258.0    397.146843   2458.711288
# Export Quantity                         3659.0     49.832960    840.289959
# Fat supply quantity (g/capita/day)      4982.0      2.058177      7.817204
# Feed                                    1213.0    184.423479   1315.564296
# Food                                    4912.0    256.288331   1349.587482
# Food supply (kcal/capita/day)           4965.0     91.577241    357.340628
# Food supply quantity (kg/capita/yr)     4876.0      9.985652     29.260778
# Import Quantity                         4929.0     59.760416    482.217302
# Losses                                  2009.0     79.947237    393.408528
# Other uses (non-food)                   1619.0     56.606529    501.900270
# Processing                              1998.0    146.564565    966.799450
# ...

# %%
csv_df.groupby('Y2018').describe()
# Out:
#           Unnamed: 0.1                                                 \
#                  count     mean       std      min       25%      50%
# Y2018
# -3396.0            1.0   8872.0       NaN   8872.0   8872.00   8872.0
# -2450.0            1.0   8939.0       NaN   8939.0   8939.00   8939.0
# -2156.0            2.0   9119.5  21.92031   9104.0   9111.75   9119.5
# -1445.0            1.0  39031.0       NaN  39031.0  39031.00  39031.0
# -1442.0            1.0  39015.0       NaN  39015.0  39015.00  39015.0
# ...                ...      ...       ...      ...       ...      ...
#  98424.0           1.0   8859.0       NaN   8859.0   8859.00   8859.0
#  109224.0          1.0  11631.0       NaN  11631.0  11631.00  11631.0
#  117038.0          1.0  43132.0       NaN  43132.0  43132.00  43132.0
#  118172.0          1.0  43128.0       NaN  43128.0  43128.00  43128.0
#  195875.0          1.0  42972.0       NaN  42972.0  42972.00  42972.0
#
# ...

# %%
csv_df.groupby('Y2018')['Area'].describe()
# Out:
#           count unique         top freq
# Y2018
# -3396.0       1      1       Egypt    1
# -2450.0       1      1       Egypt    1
# -2156.0       2      1       Egypt    2
# -1445.0       1      1  Mozambique    1
# -1442.0       1      1  Mozambique    1
# ...         ...    ...         ...  ...
#  98424.0      1      1       Egypt    1
#  109224.0     1      1    Ethiopia    1
#  117038.0     1      1     Nigeria    1
#  118172.0     1      1     Nigeria    1
#  195875.0     1      1     Nigeria    1
#
# [4591 rows x 4 columns]

# %%
print(csv_df.shape)
# Out:
# (60942, 14)

# %%
csv_df.groupby('Element Code').describe()
# Out:
#              Unnamed: 0.1                                                 \
#                     count          mean           std      min       25%
# Element Code
# 1000 tonnes           1.0  22377.000000           NaN  22377.0  22377.00
# 5072               4232.0  30628.068053  17697.628084     13.0  15072.75
# 511                  45.0  29498.400000  17791.564368      0.0  14362.00
# 5123               2009.0  31003.154803  17688.945273     18.0  15961.00
# 5131               2010.0  30808.225871  17506.301247     19.0  17436.50
# 5142               4941.0  30470.311880  17518.898976     22.0  15261.00
# 5154               1732.0  31167.591224  17919.707532     20.0  15470.25
# 5170               4655.0  30250.140279  17536.502826     21.0  14982.00
# 5171                555.0  21995.459459  15323.266683   1724.0   7349.00
# 5301               5295.0  30338.044759  17556.434612      1.0  15006.50
# 5511               3880.0  31148.207216  17609.967855     11.0  16661.75
# ...

# %%
csv_df.groupby('Area').sum()
# Out:
# <ipython-input-43-b96fb15fef6a>:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   csv_df.groupby('Area').sum()
#                              Unnamed: 0.1  Unnamed: 0  Area Code  Item Code  \
# Area
# Algeria                            861328      861328       5252    3532053
# Angola                            2882888     2882888       9968    3819908
# Benin                             4342015     4342015      68105    3453692
# Botswana                          6491069     6491069      27560    3704902
# Burkina Faso                      8600536     8600536     328297    3778795
# Cabo Verde                       13706378    13706378      44065    3394130
# Cameroon                         23811870    23811870      46720    3916078
# ...

# %%
csv_df.groupby('Y2015')['Element'].describe()
# Out:
#           count unique                            top freq
# Y2015
# -3161.0       1      1                Stock Variation    1
# -2152.0       1      1                Stock Variation    1
# -1284.0       1      1                Stock Variation    1
# -907.0        1      1                Stock Variation    1
# -887.0        1      1                Stock Variation    1
# ...         ...    ...                            ...  ...
#  92443.0      1      1  Total Population - Both sexes    1
#  100835.0     1      1  Total Population - Both sexes    1
#  110798.0     1      1       Domestic supply quantity    1
#  111663.0     1      1                     Production    1
#  181137.0     1      1  Total Population - Both sexes    1
#
# [4520 rows x 4 columns]

# %%
csv_df.groupby('Item').sum()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-84-e09902d83e83> in <cell line: 1>()
# ----> 1 csv_df.groupby('Item').sum(include='all')
#
# TypeError: GroupBy.sum() got an unexpected keyword argument 'include'

# %%
csv_df.groupby('Item').describe(include='all')
# Out:
#                     Unnamed: 0.1                                              \
#                            count unique top freq          mean           std
# Item
# Alcohol, Non-Food          283.0    NaN NaN  NaN  31220.855124  17418.424078
# Alcoholic Beverages        564.0    NaN NaN  NaN  30738.260638  17338.551640
# Animal Products            135.0    NaN NaN  NaN  29507.400000  17658.292365
# Animal fats                639.0    NaN NaN  NaN  30715.414710  17665.218993
# Apples and products        517.0    NaN NaN  NaN  30785.117988  17404.689099
# ...                          ...    ...  ..  ...           ...           ...
# Vegetables, Other          583.0    NaN NaN  NaN  30119.790738  17585.106490
# Vegetal Products           135.0    NaN NaN  NaN  29504.400000  17658.292365
# Wheat and products         653.0    NaN NaN  NaN  29490.474732  17765.098026
# Wine                       497.0    NaN NaN  NaN  30803.223340  17382.277451
# ...

# %%
 csv_df.groupby('Unit').describe()
# Out:
#                 Unnamed: 0.1                                              \
#                        count          mean           std   min       25%
# Unit
# 1000 persons            45.0  29498.400000  17791.564368   0.0  14362.00
# 1000 tonnes          40930.0  30479.821231  17626.709044   1.0  15235.25
# g/capita/day         10046.0  30452.165539  17526.213476   3.0  15228.00
# kcal/capita/day       5014.0  30479.601316  17525.501005   2.0  15254.00
# kg                    4905.0  30434.688277  17518.357114  23.0  15238.00
#
#                                             Unnamed: 0                ...  \
#                      50%       75%      max      count          mean  ...
# Unit                                                                  ...
# 1000 persons     29508.0  44446.00  59549.0       45.0  29498.400000  ...
# 1000 tonnes      30560.5  45706.75  60937.0    40930.0  30479.821231  ...
# g/capita/day     30319.5  45711.00  60941.0    10046.0  30452.165539  ...
# ...

# %%
 csv_df.groupby('Element')['Y2015'].describe()
# Out:
#                                          count          mean           std  \
# Element
# Domestic supply quantity                5245.0    385.413451   2400.248993
# Export Quantity                         3703.0     42.563994    910.217891
# Fat supply quantity (g/capita/day)      4974.0      2.057849      7.801911
# Feed                                    1177.0    191.206644   1373.447354
# Food                                    4901.0    251.450949   1329.720375
# Food supply (kcal/capita/day)           4955.0     91.500101    356.076420
# Food supply quantity (kg/capita/yr)     4865.0     10.142884     29.625873
# Import Quantity                         4911.0     54.371505    467.826618
# Losses                                  2009.0     77.371329    376.049594
# Other uses (non-food)                   1667.0     39.744697    240.789221
# Processing                              1995.0    144.325313    920.450961
# ...

# %%
csv_df.groupby('Element')['Y2015'].sum()
# Out:
# Element
# Domestic supply quantity                  2021493.55
# Export Quantity                            157614.47
# Fat supply quantity (g/capita/day)          10235.74
# Feed                                       225050.22
# Food                                      1232361.10
# Food supply (kcal/capita/day)              453383.00
# Food supply quantity (kg/capita/yr)         49345.13
# Import Quantity                            267018.46
# Losses                                     155439.00
# Other uses (non-food)                       66254.41
# Processing                                 287929.00
# Production                                1947019.39
# Protein supply quantity (g/capita/day)      11833.95
# Residuals                                   30045.00
# Seed                                        23976.82
# Stock Variation                             34910.99
# Total Population - Both sexes             1058081.00
# Tourist consumption                           349.00
# ...

# %%
csv_df.groupby('Element')['Y2017'].sum()
# Out:
# Element
# Domestic supply quantity                  2088198.10
# Export Quantity                            182338.80
# Fat supply quantity (g/capita/day)          10253.84
# Feed                                       223705.68
# Food                                      1258888.28
# Food supply (kcal/capita/day)              454681.00
# Food supply quantity (kg/capita/yr)         48690.04
# Import Quantity                            294559.09
# Losses                                     160614.00
# Other uses (non-food)                       91645.97
# Processing                                 292836.00
# Production                                2030056.89
# Protein supply quantity (g/capita/day)      11842.45
# Residuals                                   35500.00
# Seed                                        24870.14
# Stock Variation                             54316.91
# Total Population - Both sexes             1112641.00
# Tourist consumption                            91.00
# ...

# %%
csv_df.groupby('Element')['Y2017'].describe(include='all')
# Out:
#                                          count          mean           std  \
# Element
# Domestic supply quantity                5258.0    397.146843   2458.711288
# Export Quantity                         3659.0     49.832960    840.289959
# Fat supply quantity (g/capita/day)      4982.0      2.058177      7.817204
# Feed                                    1213.0    184.423479   1315.564296
# Food                                    4912.0    256.288331   1349.587482
# Food supply (kcal/capita/day)           4965.0     91.577241    357.340628
# Food supply quantity (kg/capita/yr)     4876.0      9.985652     29.260778
# Import Quantity                         4929.0     59.760416    482.217302
# Losses                                  2009.0     79.947237    393.408528
# Other uses (non-food)                   1619.0     56.606529    501.900270
# Processing                              1998.0    146.564565    966.799450
# ...

# %%
csv_df.describe(include='all')b
# Out:
#         Unnamed: 0.1    Unnamed: 0     Area Code   Area      Item Code  \
# count   60942.000000  60942.000000  60942.000000  60942   60942.000000
# unique           NaN           NaN           NaN     50            NaN
# top              NaN           NaN           NaN  Kenya            NaN
# freq             NaN           NaN           NaN   1560            NaN
# mean    30470.500000  30470.500000    134.282088    NaN    2691.453431
# std     17592.584389  17592.584389     72.692510    NaN    1052.588963
# min         0.000000      0.000000      4.000000    NaN    2501.000000
# 25%     15235.250000  15235.250000     74.000000    NaN    2562.000000
# 50%     30470.500000  30470.500000    136.000000    NaN    2630.000000
# 75%     45705.750000  45705.750000    195.000000    NaN    2775.000000
# max     60941.000000  60941.000000   1014.000000    NaN  260000.000000
#
#                            Item Element Code                   Element  \
# ...

# %%
my_tuppy = (1,2,5,8)
my_tuppy[2] = 6

print(my_tuppy)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-72-eeab08298dd6> in <cell line: 2>()
#       1 my_tuppy = (1,2,5,8)
# ----> 2 my_tuppy[2] = 6
#       3
#       4 print(my_tuppy)
#
# TypeError: 'tuple' object does not support item assignment

# %%
s = [['him','sell'],[90,28,43]]

print(s[0][1][1])
# Out:
# e

# %%
csv_df.groupby('Area')['Area'].sum()
# Out:
# Area
# Algeria                        AlgeriaAlgeriaAlgeriaAlgeriaAlgeriaAlgeriaAlge...
# Angola                         AngolaAngolaAngolaAngolaAngolaAngolaAngolaAngo...
# Benin                          BeninBeninBeninBeninBeninBeninBeninBeninBeninB...
# Botswana                       BotswanaBotswanaBotswanaBotswanaBotswanaBotswa...
# Burkina Faso                   Burkina FasoBurkina FasoBurkina FasoBurkina Fa...
# Cabo Verde                     Cabo VerdeCabo VerdeCabo VerdeCabo VerdeCabo V...
# Cameroon                       CameroonCameroonCameroonCameroonCameroonCamero...
# Central African Republic       Central African RepublicCentral African Republ...
# Chad                           ChadChadChadChadChadChadChadChadChadChadChadCh...
# Citrus, Other                                                      Citrus, Other
# Comoros                        ComorosComorosComorosComorosComorosComorosComo...
# ...

# %%
csv_df.groupby('Area')['Element','Y2015'].describe()
# Out:
# <ipython-input-82-69d76b5ad8ff>:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   csv_df.groupby('Area')['Element','Y2015'].describe()
#                               Y2015                                        \
#                               count        mean          std     min  25%
# Area
# Algeria                      1268.0  255.566562  1520.753940   -19.0  0.0
# Angola                       1378.0  152.079586  1007.390589  -114.0  0.0
# Benin                        1260.0   85.858040   483.166264  -161.0  0.0
# Botswana                     1369.0   16.818736   112.182093   -12.0  0.0
# Burkina Faso                 1372.0   74.855117   587.007670  -294.0  0.0
# Cabo Verde                   1229.0   11.829886   103.952025   -10.0  0.0
# Cameroon                     1443.0  156.078115   856.316567  -117.0  0.0
# Central African Republic     1296.0   22.288071   162.514838   -35.0  0.0
# ...

# %%
csv_df.isnull().sum()
# Out:
# Unnamed: 0.1       0
# Unnamed: 0         0
# Area Code          0
# Area               0
# Item Code          0
# Item               1
# Element Code       1
# Element            2
# Unit               2
# Y2014           1588
# Y2015           1548
# Y2016           1537
# Y2017           1506
# Y2018           1436
# dtype: int64

# %%
csv_df.groupby('Item').sum()
# Out:
# <ipython-input-87-ce626981bcdb>:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   csv_df.groupby('Item').sum()
#                      Unnamed: 0.1  Unnamed: 0  Area Code  Item Code  \
# Item
# Alcohol, Non-Food         8835502     8835502      38447     752497
# Alcoholic Beverages      17336379    17336379      75016    1649136
# Animal Products           3983499     3983499      18060     397035
# Animal fats              19627150    19627150      85279    1882494
# Apples and products      15915906    15915906      69280    1352989
# ...                           ...         ...        ...        ...
# Vegetables, Other        17559838    17559838      77779    1518715
# Vegetal Products          3983094     3983094      18060     391905
# ...

# %%
csv_df.groupby('Area')['Y2017'].sum()
# Out:
# Area
# Algeria                         325644.27
# Angola                          229159.57
# Benin                           124771.22
# Botswana                         22101.30
# Burkina Faso                    101855.07
# Cabo Verde                       14650.74
# Cameroon                        232030.43
# Central African Republic         29937.00
# Chad                             71594.68
# Citrus, Other                        0.00
# Comoros                             59.84
# Congo                            41181.68
# CÃÂ´te d'Ivoire                224599.01
# Djibouti                         22729.91
# Egypt                           866379.92
# Eswatini                         54343.33
# Ethiopia                        448683.76
# Ethiopia PDR                         0.00
# Gabon                            27979.64
# Gambia                           23154.18
# Ghana                           337599.06
# Guinea                           98138.87
# ...

# %%
csv_df.groupby('Element').sum()
# Out:
# <ipython-input-99-ba73ceef1729>:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   csv_df.groupby('Element').sum()
#                                         Unnamed: 0.1  Unnamed: 0  Area Code  \
# Element
# Domestic supply quantity                   160639947   160639947     708993
# Export Quantity                            136487168   136487168     599728
# Fat supply quantity (g/capita/day)         152963739   152963739     675050
# Feed                                        39188525    39188525     176272
# Food                                       150553811   150553811     663295
# Food supply (kcal/capita/day)              152824721   152824721     674057
# Food supply quantity (kg/capita/yr)        149282146   149282146     658446
# ...

# %%
csv_df.groupby('Element').sum()
